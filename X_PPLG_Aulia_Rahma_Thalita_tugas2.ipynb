# %% [markdown]
# <a href="https://colab.research.google.com/github/auliarahmaa21/Tugas-untuk-pembelajaran-repositori-github-Dasar-dasar-PPLG-X/blob/main/X_PPLG_Aulia_Rahma_Thalita_tugas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 2 praktik membuat type data dan variabel
#
# NAMA KELOMPOK: Antodonatur
#
# NAMA ANGGOTA:
# 1. Adikto Dwi Pratama Hamdi
# 2. Aulia Rahma Thalita
# 3. Evan Fadhilah
# 4. Gavin Atthallah Dewandri
# 5. Ghaisan Faiza Rizky
# 6. Safira Hana Rosava
# 7. Reno Ruzain Arafah

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "Masukkan Nama (1 Kata) : ";
#     cin >> namaSiswa;
#
#     cout << "Masukkan Umur Anda     : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " tahun ya!" << endl;
#     return 0;
# }
# Out:
# Writing input_data.cpp

# %%
# !g++ input_data.cpp -o input_data
# !./input_data
# Out:
# Masukkan Nama (1 Kata) : Aulia
# Masukkan Umur Anda     : 15
#
# Halo Aulia, ternyata umur kamu 15 tahun ya!
